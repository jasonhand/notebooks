# %% [markdown]
# ## Google Restaurant Reviews and Suggestions

# %% [markdown]
# ### Environment Setup
# Install packages.
# >Secrets (API keys) **ARE USED** in this demo.
#
# To use this code you'll need to upload a `.env` file to the root directory for this notebook. Click on `File Browser` (folder) icon to view the directory. All files starting with a period are hidden by default. Click the eye icon to view them.
#
# View the [README](https://console.cloud.google.com/vertex-ai/colab/notebooks?project=vertexaiwebinar&supportedpurview=project&activeNb=projects%2Fvertexaiwebinar%2Flocations%2Fus-central1%2Frepositories%2Fccc4213c-e5f1-4017-a1ef-f1984b49b4dc) for information on how to obtain and use your own API keys from an `.env` file.

# %%
# !pip install --upgrade google-cloud-aiplatform
# !pip install python-dotenv
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /usr/local/lib/python3.10/dist-packages (1.39.0)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.11.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.23.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (23.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.8.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (3.12.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.11.0)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.62.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.17.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.51.3)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.48.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.7.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.13.0)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.10/dist-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.23.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2023.11.17)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.5.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.0)

# %% [markdown]
# ### Look Up Restaurants and Send to Text-Unicorn
# Call the Google Places API
#
# Uses the `text-unicorn@001` model to generate a summarized list with the higest rated at the top.

# %%
from google.colab import auth as google_auth
google_auth.authenticate_user()

# Used to pull in API Keys/Secrets
from dotenv import load_dotenv
import os
# Load environment variables from .env file
load_dotenv()
api_key = os.getenv("api_key")
project_id = os.getenv("project_id")

import requests
import math
import vertexai

from vertexai.preview.language_models import TextGenerationModel

# Define the search radius and other parameters
location_name = 'Erie, Co'  # Replace with the city or town of your choice
radius = '20000'  # 20000 is approx 20 miles
place_type = 'restaurant'
keyword = 'mexican'

# Haversine function to calculate distance
def haversine(lat1, lon1, lat2, lon2):
    """Calculate the great circle distance in kilometers between two points
    on the earth (specified in decimal degrees)"""
    lat1, lon1, lat2, lon2 = map(math.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a))
    r = 3956  # Radius of earth in kilometers. Use 3956 for miles
    return c * r

# Function to convert a location into latitude and longitude
def get_location_coordinates(api_key, location):
    geocode_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={api_key}"
    response = requests.get(geocode_url)
    data = response.json()
    if 'results' in data and len(data['results']) > 0:
        latitude = data['results'][0]['geometry']['location']['lat']
        longitude = data['results'][0]['geometry']['location']['lng']
        return f"{latitude},{longitude}"
    else:
        return None

# Get the latitude and longitude for the location
location_coordinates = get_location_coordinates(api_key, location_name)
if not location_coordinates:
    raise Exception("Failed to get location coordinates. Check your location name and API key.")

# Split the coordinates into latitude and longitude for distance calculation
location_lat, location_lon = map(float, location_coordinates.split(','))

# Endpoint URL for the Nearby Search request
url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={location_coordinates}&radius={radius}&type={place_type}&keyword={keyword}&key={api_key}"

# Make a GET request to the Google Maps API
response = requests.get(url)
data = response.json()

# Collecting restaurant information
restaurant_details_string = ""

if data.get('results'):
    for place in data['results']:
        name = place.get('name', 'No name available')
        address = place.get('vicinity', 'No address available')
        rating = place.get('rating', 'No rating available')
        place_id = place.get('place_id', 'No place ID available')  # Extract place_id
        open_now = 'No information available'
        if 'opening_hours' in place and 'open_now' in place['opening_hours']:
            open_now = 'Yes' if place['opening_hours']['open_now'] else 'No'
        place_lat = place['geometry']['location']['lat']
        place_lon = place['geometry']['location']['lng']
        distance = haversine(location_lat, location_lon, place_lat, place_lon)

        # Append restaurant information to the string
        restaurant_details_string += f"Name: {name}, Address: {address}, Rating: {rating}, Open Now: {open_now}, Distance: {distance:.2f} miles, , Place ID: {place_id}\n\n"
else:
    print("No nearby restaurants found or an error occurred.")

#paste in reviews
def get_place_details(api_key, place_id):
    """Fetch place details for a given place_id from the Google Places API."""
    details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&key={api_key}"

    response = requests.get(details_url)
    data = response.json()

    if data['status'] == 'OK':
        # Extract and print details
        details = data['result']
        name = details.get('name', 'No name available')
        address = details.get('formatted_address', 'No address available')
        phone = details.get('formatted_phone_number', 'No phone number available')
        website = details.get('website', 'No website available')
        place_id = place.get('place_id', 'No place ID available')  # Extract place_id

        print(f"Name: {name}")
        print(f"Address: {address}")
        print(f"Phone Number: {phone}")
        print(f"Website: {website}")

# Prepare the content for the language model
prompt = "You are a local food afficienado. I need your help choosing a restaurant to visit. Here are some local restaurants: "
print("#####################################")
print(prompt)
print(restaurant_details_string)
full_prompt = prompt + restaurant_details_string + "\n\n Summarize and order these restaurants by rating with the highest at the top. Additionally, write a few reasons why someone might choose the first 3 restaurants on the list and provide a corresponding URL for each restaurant's website."
print("#####################################")

def predict_large_language_model_sample(
    project_id: str,
    model_name: str,
    temperature: float,
    max_decode_steps: int,
    top_p: float,
    top_k: int,
    content: str,
    location: str = "us-central1",
    tuned_model_name: str = "",
    ):
    """Predict using a Large Language Model."""
    vertexai.init(project=project_id, location=location)
    model = TextGenerationModel.from_pretrained(model_name)
    if tuned_model_name:
        model = model.get_tuned_model(tuned_model_name)
    response = model.predict(
        content,
        temperature=temperature,
        max_output_tokens=max_decode_steps,
        top_k=top_k,
        top_p=top_p,)
    print("##### Vertex AI - text-unicorn Response ######")
    print("##### ------------------------------- ######")
    print(f"{response.text}")

# Call the function to use the language model
predict_large_language_model_sample(project_id, "text-unicorn@001", 0.15, 1000, 0.7, 30, full_prompt, "us-central1")
# Out:
# #####################################
# You are a local food afficienado. I need your help choosing a restaurant to visit. Here are some local restaurants:
# Name: Tequila's Family Mexican Restaurant, Address: 12020 Pennsylvania St, Thornton, Rating: 4.2, Open Now: Yes, Distance: 10.03 miles, , Place ID: ChIJg_2L-DN0bIcRMwQn9Yp1oAo
#
# Name: El Mirador Mexican Restaurant, Address: 11370 Huron St, Northglenn, Rating: 4.4, Open Now: Yes, Distance: 10.56 miles, , Place ID: ChIJWQxkTNd1bIcRLxnv6tU8zqs
#
# Name: Hacienda Colorado, Address: 10422 Town Center Dr, Westminster, Rating: 4.2, Open Now: Yes, Distance: 11.35 miles, , Place ID: ChIJ6ZWIs4CJa4cRIv72q1jsgL0
#
# Name: La Estrellita, Address: 45 N Main St, Brighton, Rating: 4.5, Open Now: Yes, Distance: 12.81 miles, , Place ID: ChIJZ6ZfmThtbIcRJo6l85no6co
#
# Name: Los Jimadores, Address: 275 S 4th Ave, Brighton, Rating: 4.2, Open Now: Yes, Distance: 13.11 miles, , Place ID: ChIJQTCMOj5tbIcRke08jqvwKIU
#
# Name: Casa Agave, Address: 451 S Pratt Pkwy, Longmont, Rating: 4.3, Open Now: Yes, Distance: 7.76 miles, , Place ID: ChIJGfokW5f5a4cRB5ofRjjXl6Y
#
# Name: Rio Grande Mexican Restaurant, Address: 1101 Walnut St, Boulder, Rating: 4.2, Open Now: Yes, Distance: 12.42 miles, , Place ID: ChIJJU2aYSbsa4cRJC5YrD0nPFs
#
# Name: 3 Margaritas, Address: 3202 E 104th Ave, Thornton, Rating: 3.8, Open Now: Yes, Distance: 12.63 miles, , Place ID: ChIJlUT1r0ZxbIcRC9Oq2QiuSoU
#
# Name: El Aguascalientes Mexican Restaurant, Address: 644 S Main St, Brighton, Rating: 4, Open Now: Yes, Distance: 12.96 miles, , Place ID: ChIJHVe2cWttbIcRC5hWYyL6jS0
#
# Name: Santiago's Mexican Restaurant, Address: 215 Main St, Longmont, Rating: 4.4, Open Now: Yes, Distance: 8.24 miles, , Place ID: ChIJn3qyZWb5a4cRLBRwz_KhWmY
#
# Name: El Tapatio Mexican Restaurant, Address: 588 Summit Blvd, Broomfield, Rating: 3.9, Open Now: Yes, Distance: 9.60 miles, , Place ID: ChIJTR_ea4WMa4cRJequlENJNzQ
#
# Name: El Azteca Mexican Food, Address: 2683 E 120th Ave, Thornton, Rating: 4.3, Open Now: Yes, Distance: 10.64 miles, , Place ID: ChIJe0T0bhd0bIcR1qrSV_wWeWc
#
# Name: Lupita's Mexican Restaurant, Address: 75 W Bridge St, Brighton, Rating: 4.4, Open Now: Yes, Distance: 12.66 miles, , Place ID: ChIJV_x1NsltbIcR6b3lfXmciwA
#
# Name: 3 Margaritas Longmont, Address: 2350 Main St, Longmont, Rating: 4.2, Open Now: Yes, Distance: 10.79 miles, , Place ID: ChIJ_ZyT_zX5a4cR2zEeFLuT2As
#
# Name: Mucho Bueno Mexican Restaurant, Address: 9740 Grant St #85, Thornton, Rating: 4.7, Open Now: Yes, Distance: 12.74 miles, , Place ID: ChIJBdjhicp3bIcRiKFG4fWvq3U
#
# Name: El Taco Loco II, Address: 909 Carbondale Dr, Dacono, Rating: 4.1, Open Now: Yes, Distance: 6.77 miles, , Place ID: ChIJ0wI1J7YObIcRkRK2fphdagY
#
# Name: Buenos Tiempos, Address: 1000 Depot Hill Rd, Broomfield, Rating: 4.5, Open Now: Yes, Distance: 8.62 miles, , Place ID: ChIJpbA7vVWLa4cRC3E7MTxvzsg
#
# Name: Si Señor! Real Mexican Food, Address: 3120 Village Vista Dr, Erie, Rating: 4.1, Open Now: Yes, Distance: 3.73 miles, , Place ID: ChIJFanim5AKbIcRyBOO2L1MYS4
#
# Name: ANA'S Mexican Grill, Address: 2821 W 120th Ave #100, Westminster, Rating: 4.4, Open Now: Yes, Distance: 9.47 miles, , Place ID: ChIJUV4SyPJ1bIcR0GZVKfRDHys
#
# Name: Santiago's Mexican Restaurant, Address: 104 N Public Rd, Lafayette, Rating: 4.3, Open Now: Yes, Distance: 4.15 miles, , Place ID: ChIJ4_1_ffr0a4cRaf2roIbZOuk
#
#
# #####################################
# ##### Vertex AI - text-unicorn Response ######
# ##### ------------------------------- ######
#  Here are the restaurants ordered by rating with the highest at the top:
#
# 1. Mucho Bueno Mexican Restaurant (4.7)
# 2. La Estrellita (4.5)
# 3. Buenos Tiempos (4.5)
# 4. El Mirador Mexican Restaurant (4.4)
# 5. Lupita's Mexican Restaurant (4.4)
# 6. Santiago's Mexican Restaurant (4.4)
# 7. ANA'S Mexican Grill (4.4)
# 8. Casa Agave (4.3)
# 9. El Azteca Mexican Food (4.3)
# 10. Santiago's Mexican Restaurant (4.3)
# 11. Hacienda Colorado (4.2)
# 12. Los Jimadores (4.2)
# 13. Rio Grande Mexican Restaurant (4.2)
# 14. Tequila's Family Mexican Restaurant (4.2)
# 15. 3 Margaritas Longmont (4.2)
# 16. El Taco Loco II (4.1)
# 17. Si Señor! Real Mexican Food (4.1)
# 18. El Aguascalientes Mexican Restaurant (4)
# 19. El Tapatio Mexican Restaurant (3.9)
# 20. 3 Margaritas (3.8)
#
# Here are a few reasons why someone might choose the first 3 restaurants on the list:
#
# 1. Mucho Bueno Mexican Restaurant: This restaurant has the highest rating on the list and is known for its authentic Mexican cuisine. The restaurant also has a friendly and welcoming atmosphere.
# 2. La Estrellita: This restaurant is also known for its authentic Mexican cuisine and has a wide variety of dishes to choose from. The restaurant also has a full bar and a patio for outdoor dining.
# 3. Buenos Tiempos: This restaurant is known for its delicious food and friendly service. The restaurant also has a great atmosphere and is a great place to relax and enjoy a meal.
#
# Here are the corresponding URLs for each restaurant's website:
#
# 1. Mucho Bueno Mexican Restaurant: https://www.muchobuenothornton.com/
# 2. La Estrellita: https://www.laestrellitabrighton.com/
# 3. Buenos Tiempos: https://www.buenostiempos.com/

# %% [markdown]
# ### Query Restaurant Reviews

# %%
import requests
import math
import os
from dotenv import load_dotenv

# Constants and Parameters
EARTH_RADIUS_MILES = 3956  # Radius of earth in miles
LOCATION_NAME = 'Erie, Co'  # Replace with the city or town of your choice
RADIUS = '20000'  # In meters (approx 20 miles)
PLACE_TYPE = 'restaurant'
KEYWORD = 'mexican'

# Load environment variables from .env file
load_dotenv()
api_key = os.getenv("api_key")
project_id = os.getenv("project_id")

# Utility Functions
def haversine(lat1, lon1, lat2, lon2):
    """Calculate the great circle distance between two points on the earth."""
    lat1, lon1, lat2, lon2 = map(math.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a))
    return c * EARTH_RADIUS_MILES

def get_location_coordinates(api_key, location):
    """Convert a location into latitude and longitude."""
    geocode_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={api_key}"
    response = requests.get(geocode_url)
    data = response.json()
    if 'results' in data and len(data['results']) > 0:
        lat = data['results'][0]['geometry']['location']['lat']
        lon = data['results'][0]['geometry']['location']['lng']
        return f"{lat},{lon}"
    return None

def get_place_details(api_key, place_id):
    """Fetch and print details for a given place_id from the Google Places API."""
    details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&key={api_key}"
    response = requests.get(details_url)
    data = response.json()

    if data['status'] == 'OK':
        details = data['result']
        print_place_details(details)
    else:
        print("Error fetching details:", data.get('status', 'Unknown error'))

def print_place_details(details):
    """Print details and reviews for a place."""
    # Basic place details
    name = details.get('name', 'No name available')
    address = details.get('formatted_address', 'No address available')
    phone = details.get('formatted_phone_number', 'No phone number available')
    website = details.get('website', 'No website available')
    rating = details.get('rating', 'No rating available')
    place_id = details.get('place_id', 'No place ID available')

    # Print basic details
    print(f"Name: {name}\nAddress: {address}\nPhone Number: {phone}\nWebsite: {website}\nRating: {rating}\nPlace ID: {place_id}\n")

    # Print reviews
    reviews = details.get('reviews', [])
    if reviews:
        print("Recent Reviews:")
        for review in reviews:
            print_review(review)

def print_review(review):
    """Print a single review."""
    author_name = review.get('author_name', 'Anonymous')
    rating = review.get('rating', 'No rating')
    text = review.get('text', '').replace('\n', ' ')
    time = review.get('relative_time_description', 'No time provided')

    print(f"Author: {author_name}\nRating: {rating}\nReview: {text}\nTime: {time}\n")
    print("\n-----------------\n")

# Main Script
location_coordinates = get_location_coordinates(api_key, LOCATION_NAME)
if not location_coordinates:
    raise Exception("Failed to get location coordinates. Check your location name and API key.")

# Endpoint URL for the Nearby Search request
url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={location_coordinates}&radius={RADIUS}&type={PLACE_TYPE}&keyword={KEYWORD}&key={api_key}"

# Make a GET request to the Google Maps API for nearby places
response = requests.get(url)
data = response.json()

# Process and display results
if data.get('results'):
    for place in data['results']:
        place_id = place.get('place_id', '')
        if place_id:
            get_place_details(api_key, place_id)
else:
    print("No nearby places found or an error occurred.")
# Out:
# Name: Tequila's Family Mexican Restaurant
# Address: 12020 Pennsylvania St, Thornton, CO 80241, USA
# Phone Number: (303) 254-5555
# Website: https://www.tequilasthornton.com/
# Rating: 4.2
# Place ID: ChIJg_2L-DN0bIcRMwQn9Yp1oAo
#
# Recent Reviews:
# Author: Peter Phakonekham
# Rating: 5
# Review: We came with a party of 6.  Food was great! For someone who’s not a huge fan of Mexican food I really enjoyed it to my liking! I got the steak dish, forgot the name. But I loved how the beef was cooked with the bell peppers! I would get it again and the service was very kind! The ice cream deep fried was super good!
# Time: 2 months ago
#
#
# -----------------
#
# Author: Sammie
# Rating: 5
# Review: 1st time here!! It was very good. I liked the food & drinks we ordered!! The waiter was nice & they were very attentive! I enjoyed the meal! It was all very good. The drinks were very good & tasty! Overall bill was decent for what we ordered! They also do have a lot of tvs on throughout the restaurant so if your into sports more than likely your game will be showing! Which is a plus for me. If ever in this area again I'd stop for some more.
# Time: 3 months ago
#
#
# -----------------
#
# Author: C
# Rating: 5
# Review: The service was excellent. Nice visit over lunch with loved ones we don't get to see often. Everyone's food was good. Love the cabbage salsa. Our four entrees: taco salad, burrito verde, a chile relleno (crispy), and a chile relleno (soft).
# Time: 4 months ago
#
#
# -----------------
#
# Author: Jason Robb
# Rating: 3
# Review: Went into Tequilas to grab some takeout tonight. I have been waiting to try it for quite some time now. When I arrived it was very busy. Typical Mexican restaurant decor and vibe when you walk in. When you first look at the menu, you may be intimidated by the sheer size of it. They have a ton of things to choose from. I decided on just trying a couple of classic dishes. The fajitas Cancun and some Enchiladas. The fajitas Cancun are a mixture of steak, shrimp, and chicken, sautéed with peppers, onions, mushrooms, and pineapple served I side of a pineapple. The mixture is seasoned pretty well. Packed with flavor. They do one of the things I hate most... serving shrimp with the tail on. I don't get that. It's so annoying. They also did not give me any tortillas for the fajitas, so that was also a little unfortunate. The beans are a little bland and under seasoned pinto beans. There is nothing to remember either good or bad. Surprisingly, the rice was EXTREMELY flavorful! It was very good. Some of the best I've had!! The Enchiladas honestly taste about as good as they looked... meh.. everything was bland and lacked flavor. The ground beef filling was greasy and bland, and the sauce was boring and bland. It comes with refried beans and rice. The rice!! *chefs kiss**  Overall, the food was ok.. the fajitas warrant another chance, so I might be back if I'm feeling a little risky!
# Time: 5 months ago
#
#
# -----------------
#
# Author: Mychele Moody
# Rating: 5
# Review: The food was great the atmosphere was even better they had a whole wall of tequila in there and I mean a two-story wall of every tequila I've ever known made two-man it was just great food! Margaritas were even better!
# Time: 3 months ago
#
#
# -----------------
#
# Name: El Mirador Mexican Restaurant
# Address: 11370 Huron St, Northglenn, CO 80234, USA
# Phone Number: (303) 252-4872
# Website: https://elmiradormexican.com/
# Rating: 4.4
# Place ID: ChIJWQxkTNd1bIcRLxnv6tU8zqs
#
# Recent Reviews:
# Author: Jon Miracle
# Rating: 5
# Review: Great food and drinks! Great and friendly service. It can be crowded and have a small wait time depending on time of day or holiday. We were asked to wait for about 15 minutes and were buzzed in around five.  Best sit down Mexican restaurant we’ve been to since moving to the area.
# Time: 3 weeks ago
#
#
# -----------------
#
# Author: Josie Jose Olivas
# Rating: 4
# Review: My youngest son recommended this Mexican restaurant. So my oldest son and my daughter wanted to try something new so we chose this place! I had the Menudo which was delicious, my daughter had a breakfast burrito that she said was okay but it was a little too salty for her tastes and my oldest son had the posole and he didn't like the fact that the meat had bones in it but he said it did taste good. Otherwise then that people were super nice the service was excellent! The sat sat us in a booth next to the handicap door which several seniors needed to use and it was just a little cold back there. I think next time I would rather not sit in that booth next to that door.
# Time: 2 weeks ago
#
#
# -----------------
#
# Author: Antony Josef Chick
# Rating: 5
# Review: You will keep coming back... I happened upon El Mirador about 6 months ago and since lost count of my visits. The huevos divorciados breakfast is a spicy delight, and the carne asada burrito is a grand meal including guacamole & sour cream, side of rice & beans and plenty of asada meat. Don't forget to indulge in the an occasional molcojete bowl, El Mirador or Costeño seafood style will leave you feeling pampered. I always pair with a tall glass of jamaica (sweet & sour hibiscus tea) to tone down the heat. Even the chips and salsa are homemade with an extra kick of flavor you will not soon forget. They do get busy at times, but I've always managed to find parking. Sadly, gift cards are not available to share, so you'll need to bring any friends with you that you wish to experience this goodness.
# Time: 3 weeks ago
#
#
# -----------------
#
# Author: Tyler E
# Rating: 5
# Review: We came on a whim. We really enjoyed it. Service was top notch. Food was very good. We will definitely come back!
# Time: a month ago
#
#
# -----------------
#
# Author: Shingo S. Ishida
# Rating: 5
# Review: Long time passerby, first time customer. Can't to this restaurant on Huron Street on a Wednesday evening for an early dinner. Place was busy and parking lot was pretty full (good signs for a restaurant). Seated without to much wait, and the server came to see us shortly after. Friendly service sand attentive throughout meal. We ordered standard Mexican fare, and was pleasantly surprised by the generous portions. Lots of seats and tables inside, with covered patio area outside. Parking lot is much bigger behind the restaurant. Recommended!
# Time: 11 months ago
#
#
# -----------------
#
# Name: Hacienda Colorado
# Address: 10422 Town Center Dr, Westminster, CO 80021, USA
# Phone Number: (303) 460-0111
# Website: https://haciendacolorado.com/locations/westminster/
# Rating: 4.2
# Place ID: ChIJ6ZWIs4CJa4cRIv72q1jsgL0
#
# Recent Reviews:
# Author: Bernard Jeremy
# Rating: 5
# Review: Huge restaurant with tons of seating, good food options, and solid service. Had a pleasant experience here after seeing a movie across the street. Would come back for sure!
# Time: a week ago
#
#
# -----------------
#
# Author: Jacqueline Telljohann
# Rating: 5
# Review: My husband and I shared: - Poblano de Pollo - Fajita Quesadilla with Grilled Steak  Both dishes were cheesy and delicious. Between the two, I'd go for the poblano first, but you can't go wrong with either. The food our family friends ordered looked great too.  I would happily come back here to try more of the menu!
# Time: 3 months ago
#
#
# -----------------
#
# Author: Brandy Marie
# Rating: 4
# Review: Nice clean restaurant. Seated quickly upon arrival. Not too busy for Saturday at 5pm. We ordered dinner for 5 people. Food was amazing!! I had spicy street tacos. Another guest had bacon wrapped shrimp meal. And another meal was the fajitas that were lightly  coated in a honey sauce which was delicious!!
# Time: 3 months ago
#
#
# -----------------
#
# Author: K Miller (Do Not Reply)
# Rating: 5
# Review: Fresh made table side guacamole was delicious, and the stuff pepper was perfectly prepared.  I'm looking forward to another visit to see what else they have.
# Time: 4 weeks ago
#
#
# -----------------
#
# Author: iwona burzynska
# Rating: 5
# Review: American Mexican restaurant with wide selection of Mexican foods. Everything was delicious but a but too heavy for our European stomachs😅 Anyways worth to try!!!
# Time: a month ago
#
#
# -----------------
#
# Name: La Estrellita
# Address: 45 N Main St, Brighton, CO 80601, USA
# Phone Number: (303) 654-9900
# Website: http://www.laestrellitarestaurant.com/
# Rating: 4.5
# Place ID: ChIJZ6ZfmThtbIcRJo6l85no6co
#
# Recent Reviews:
# Author: Yolanda Ponce
# Rating: 4
# Review: This is a quaint little place set in the corner street. There is outside sitting and as you walk in it feels like you are walking into an underground atmosphere where you find the inside sitting.  I had the Healthy Lime Chicken Tacos which came with a side of beans 🌮 🤤.
# Time: 5 months ago
#
#
# -----------------
#
# Author: Juanita Hill
# Rating: 5
# Review: Excellent!  Was a frequent visitor to the Westminster years ago.   Was sad to see it shut down.   Luckily I live close enough to the Brighton location..look forward to dining on the patio this summer.   Great margaritas!
# Time: a week ago
#
#
# -----------------
#
# Author: Coach Steve Toth
# Rating: 5
# Review: Place was very busy and I still got my dinner pretty fast. Service was awesome. The single fajita option was unique and excellent. The salsa was a little too heavy on tomatoes for my taste. Overall I highly recommend the restaurant.
# Time: 8 months ago
#
#
# -----------------
#
# Author: Nicole O
# Rating: 5
# Review: Love this place! Used to live in CO, so used to go there then, but still make sure to go whenever we're in town. Last time, we had a large party for a celebration and the staff was beyond accommodating to our particular needs. Great good, great staff, great place. The wait to get in sometimes, because they're so busy, is definitely worth it!!!
# Time: a month ago
#
#
# -----------------
#
# Author: Nicole Hall
# Rating: 4
# Review: Food was delicious. Definitely recommend you try the Pink Cadillac Margarita. It's delicious 😋.  Combo #7 was perfect!!! Try it out!  End your meal with the dessert nachos!!! You won't be disappointed.  Alexis was an awesome server and!!
# Time: 9 months ago
#
#
# -----------------
#
# Name: Los Jimadores
# Address: 275 S 4th Ave, Brighton, CO 80601, USA
# Phone Number: (303) 637-0300
# Website: http://losjimadoresrestaurant.net/
# Rating: 4.2
# Place ID: ChIJQTCMOj5tbIcRke08jqvwKIU
#
# Recent Reviews:
# Author: Laura S
# Rating: 5
# Review: Have been coming to this restaurant for years and just now getting around to finally writing a review! This place is my favorite Mexican restaurant in town. They offer a lot of authentic dishes but also cater to the Tex Mex side of the house in my opinion. The combination for two has been a favorite of mine for years. It’s plenty of food for two people and it is a great mix of foods to try and enjoy. My husband is a huge fan of the super burrito, except he’s a little picky and likes it without guacamole or tomatoes. Every time we dine in the service has always been friendly and quick as well. This place can get pretty busy on the weekends around dinner time, so there might be a short wait. I recently ordered one of the fish dishes as I was craving it for sometime, however I wasn’t as impressed as I have been with everything else on the menu. It was pretty bland and overly fried making it difficult to eat. I really enjoy the chips and salsa with the side of pickled cabbage that they bring out. The atmosphere of this place is pretty great also, it really ties the whole Mexican restaurant thing together. Overall, I highly recommend this place for some good authentic Mexican dishes.
# Time: 5 months ago
#
#
# -----------------
#
# Author: Mark Barrientez
# Rating: 5
# Review: Food was great. I had the burrito. Steak was good, not dry. I'm from Texas and was impressed on the authenticity. Sign says family owned. They had a good cucumber margarita.
# Time: 5 months ago
#
#
# -----------------
#
# Author: Manuel BarizonteBig Dominican Bear
# Rating: 5
# Review: I'VE BEEN COMING HERE FOR YEARS AND IT GETS BETTER AND BETTER EVERY TIME WE COME FROM DENVER COLORADO TO EAT AND HAVE A GREAT EXPERIENCE LOVE THE FAMILY AND FRIENDS THIS RESTAURANT ROCKS AND THE FOOD IS WORTH EVERY PENNY DEFINITELY BIG DOMINICAN 🐻 BEAR APPROVED MUST TRY THIS HIDDEN GEM👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼
# Time: 4 months ago
#
#
# -----------------
#
# Author: Jennifer Lonnes
# Rating: 4
# Review: Booth enclosure had torn upholstery and chunks of paint fallen off the wall. Still, decor is colorful and cheery. I had to get my own silverware roll, waitress was nice. Food was good.
# Time: 4 months ago
#
#
# -----------------
#
# Author: Teresa Piedra
# Rating: 4
# Review: I'll admit, I'm picky when it comes to authentic food. This place has my vote. Loved the soft chile relleno!
# Time: 4 months ago
#
#
# -----------------
#
# Name: Casa Agave
# Address: 451 S Pratt Pkwy, Longmont, CO 80501, USA
# Phone Number: (720) 494-0777
# Website: https://www.casaagaverestaurant.com/
# Rating: 4.3
# Place ID: ChIJGfokW5f5a4cRB5ofRjjXl6Y
#
# Recent Reviews:
# Author: Ana Mihaela Lucaci
# Rating: 5
# Review: Big portions and delicious. Besides our entrees, we got chips and salsa - a bit on the spicy side. Dishes were big enough for leftovers, especially since we wanted lo leave room for dessert. The ice-cream was huge, enough for 2 people. We were seated in the side room where we could only hear the ambiance from the main room (mariachi) and the atmosphere didn't transfer. A couple of TVs on the walls will help you stay up to date on sports.
# Time: 6 months ago
#
#
# -----------------
#
# Author: Lance Jones
# Rating: 5
# Review: Wonderful food and the service is really next level. It starts with chips and salsa hitting the table as we're sitting down and it just gets better from there. I was gnawing on ribs with sauce up to my elbows when the waiter appeared with a stack of napkins, without my having to ask. And there were more examples of them actively anticipating our needs during the meal, attentively and politely. A warm, welcoming place that has really become my favorite Mexican restaurant.
# Time: 2 weeks ago
#
#
# -----------------
#
# Author: Haley Hinson
# Rating: 5
# Review: We are from out of town and wanted some delicious Mexican food! We chose right! Casa Agave is the place to be on a Friday night! Live music, great food, fantastic drinks and service from Carmela. Highly suggest the habanero salsa! The fajitas for 2 are more than enough, we had plenty of leftovers to take back to the hotel. Wish we lived in the area so we could visit again.
# Time: 5 months ago
#
#
# -----------------
#
# Author: Mary Ellen Weeks
# Rating: 5
# Review: While visiting family in Colorado, we were in Longmont, and we went to dinner here. The food was amazing and the service was even better!! I would definitely recommend anyone to try the Casa Agave.
# Time: 4 months ago
#
#
# -----------------
#
# Author: Vance Mo
# Rating: 5
# Review: It's been a long time (pre covid) since I've sat in a restaurant where EVERY single visible team member is focused on working together to get fast quality service to all guests. The urgency they put forward gives me hope that people still care. Also The portions are big and food hot and fresh. Took a bit to get the food but food was hot and was the peak of dinner. I review this based on the eyes of someone with over 20yrs in the restaurant industry from server to GM.
# Time: 3 weeks ago
#
#
# -----------------
#
# Name: Rio Grande Mexican Restaurant
# Address: 1101 Walnut St, Boulder, CO 80302, USA
# Phone Number: (303) 444-3690
# Website: https://riograndemexican.com/locations/boulder/
# Rating: 4.2
# Place ID: ChIJJU2aYSbsa4cRJC5YrD0nPFs
#
# Recent Reviews:
# Author: Binit Banerjee
# Rating: 4
# Review: Stopped here for lunch on a Wednesday afternoon. The place was nice with prompt service. We sat in the outdoor seating which was nice with a great view of the mountains.  I tried the taco combo with 2 mahi and 1 Baja. I liked the Baja more and had taken the side of veggies. My wife got the steak fajita. I really loved it and recommend this for sure. The steak was perfectly medium rare and tasted well. One of my friends got the rio classic chile rellenos which was also very good. We also got the chicken enchiladas which was great as well. Overall a great place
# Time: 4 months ago
#
#
# -----------------
#
# Author: Jeff C
# Rating: 5
# Review: Rio Grande Mexican Restaurant is a true taste of Mexico right in the heart of Boulder. From the moment you step inside, you're transported to a vibrant and lively atmosphere that perfectly captures the essence of Mexican culture. The colorful decor, festive music, and warm hospitality create an ambiance that's both inviting and energizing.  When it comes to the food at Rio Grande, prepare for a fiesta of flavors. Their menu is a culinary journey through the diverse regions of Mexico, featuring authentic dishes made with love and care. From sizzling fajitas and savory enchiladas to mouthwatering tacos and flavorful guacamole, each bite is a celebration of Mexican cuisine. The use of fresh ingredients and traditional spices elevates the dishes to new heights, satisfying even the most discerning palate.  The service at Rio Grande is exceptional, with a friendly and attentive staff that goes above and beyond to ensure a memorable dining experience. From the moment you're seated to the last sip of your margarita, the staff is dedicated to providing prompt and personalized service, catering to your every need.  Rio Grande Mexican Restaurant is a haven for food enthusiasts and lovers of Mexican cuisine. The combination of flavorful food, excellent service, and lively ambiance makes it a must-visit destination for those seeking an authentic and enjoyable dining experience. Whether you're looking to indulge in a festive night out with friends or simply craving a taste of Mexico, Rio Grande delivers an unforgettable culinary adventure that will leave you wanting more.
# Time: 6 months ago
#
#
# -----------------
#
# Author: Brandy Houston
# Rating: 3
# Review: Upon walking it was welcoming. Server was okay . Food is not mexican food ..it's Mexicant . No flavor .. My child said  the queso tasted like melted sandwich cheese ☺️ and he was absolutely right about that . Sopapillas were the best thing we enjoyed and the water was delightful .
# Time: 5 months ago
#
#
# -----------------
#
# Author: LAFOTODENATALIE Houston
# Rating: 4
# Review: This was my first time visiting the restaurant and I enjoyed the cozy atmosphere and a nice view on the mountain. I ordered a chicken tortilla soup and mini mahi mahi taco , as well as salad with greens, tomatoes and avocado . The soup wasn’t very good and the chicken was too rubbery and I left it on the bottom of the plate . I did like the fish taco and the salad . My Server  was very good !
# Time: 6 months ago
#
#
# -----------------
#
# Author: Hela Tyred
# Rating: 4
# Review: Got the lunch taco combo. Mahi-Mahi, carnitas, and lime chicken. Mahi-mahi was amazing. Highly recommend. Very flavorful. Other were okay. Carnitas seemed pretty bland to me. Good texture though Amazing service and good vibe. Definitely a Boulder kinda place
# Time: 2 months ago
#
#
# -----------------
#
# Name: 3 Margaritas
# Address: 3202 E 104th Ave, Thornton, CO 80233, USA
# Phone Number: (303) 280-0166
# Website: http://www.3margaritastogo.com/
# Rating: 3.8
# Place ID: ChIJlUT1r0ZxbIcRC9Oq2QiuSoU
#
# Recent Reviews:
# Author: Stephen Smith
# Rating: 5
# Review: Great food always busy which is a great sign.  Reasonable prices. You have to try the molcajeta! It can feed two easily! I also get the shrimp cocktail, it's a meal by itself! The Carne asada is amazing. Another must try is the pescado fritz! It's a whole fried snapper in a red sauce. Get the sauce on the side to dip in, it's very spicy.
# Time: 2 months ago
#
#
# -----------------
#
# Author: Haley
# Rating: 5
# Review: Great place for lunch of dinner. Good location with ample parking The food here was hot and fresh. Average $20 each plate. Our service was very knowledgeable and helpful.
# Time: 4 months ago
#
#
# -----------------
#
# Author: Tommie Mitchell
# Rating: 5
# Review: Always have a great time and experience. Great food as well
# Time: 3 months ago
#
#
# -----------------
#
# Author: Jason Robb
# Rating: 4
# Review: I eat here quite often. 90% of the time I get my food delivered through uber eats and its always fast and delicious! Tonight I got the vegetable fajitas, chorizo nachos, a crispy chile rellano and a taco salad. First the fajitas. They were on par with some of the best fajitas I've ever had!! A pile of onions, peppers, mushrooms, zucchini and broccoli that is well seasoned and cooked to a perfect tenderness. The broccoli still had a nice bite to it, not to hard, not too soft. It was accompanied by a side of well seasoned black beans and rice. The rice by itself is a touch bland but when mixed with the beans, its fantastic! The chorizo nachos are a big portion of homemade chips with typical nacho toppings. Mean, beans, cheese, guac and sour cream topped with fresh tomatoes. Id suggest adding lettuce to step it up even more! The ratio of toppings to chips was nice as well. No chip went un-topped lol. The crispy rellano was indeed not crispy. Tasted great and attribute the soggyness to being packed in a container hot and steamed in delivery. The taco salad is basic. The ground beef is a little bland, could use some salt, but when topped with the house salsa (WHICH IS HOT!) It was very nice. The deliver the taco shell bowl separately from the salad mix which most places don't and it's key to receiving a crispy shell instead of a flimsy soggy bowl! Thank you for that.  This place is consistently very good. I can't speak on anything in restaurant such as service or cleanliness, but the food is a sold 8.72/10 and would recommend giving it a try!
# Time: 8 months ago
#
#
# -----------------
#
# Author: Jim Cullip
# Rating: 4
# Review: It's been a while since I've been to this location, but the food didn't seem as good as I remembered it. However, it wasn't too bad. The service was a bit lacking. The waiter was nice but didn't come around much and we weren't offered a refill on our drinks or chips and salsa.
# Time: a year ago
#
#
# -----------------
#
# Name: El Aguascalientes Mexican Restaurant
# Address: 644 S Main St, Brighton, CO 80601, USA
# Phone Number: (303) 637-7500
# Website: https://eltacolocobrighton.com/index.html
# Rating: 4
# Place ID: ChIJHVe2cWttbIcRC5hWYyL6jS0
#
# Recent Reviews:
# Author: Luis Gonzalez
# Rating: 5
# Review: The food was amazing the day we went the serive was great. And the servings are huge. My wife had the carnitas and I had a stake chimichanga.
# Time: 5 months ago
#
#
# -----------------
#
# Author: D K
# Rating: 5
# Review: Just stopped in and needed a few handheld burritos early on a Sunday morning ..reasonable prices and delicious burritos! The lady at the front was very nice. A little longer wait but that was because they were making things fresh and grilling the tortilla. Thanks!
# Time: 2 months ago
#
#
# -----------------
#
# Author: Gina Trujillo
# Rating: 1
# Review: No doubt that the food is good, and you get a great portion for a great price. But the service is not so great they take forever to get you anything or to do anything and not overly friendly and it smells really bad like sewer in there. There is very crowded. I think this facility should move somewhere else where it could do so much better, the smell of sewer is disgusting
# Time: a month ago
#
#
# -----------------
#
# Author: Michael Crowley
# Rating: 5
# Review: Gave this place a shot as we were driving through, we are happy that we did. Food was great, service was quick and very helpful, atmosphere was well done, plenty of menu options for everyone. Recommend checking it out to anyone. We plan to go back next time we are in town.
# Time: 4 months ago
#
#
# -----------------
#
# Author: Manuel Reyes
# Rating: 5
# Review: Great authentic Mexican food from the tacos and burritos to pozole and menudo!
# Time: a month ago
#
#
# -----------------
#
# Name: Santiago's Mexican Restaurant
# Address: 215 Main St, Longmont, CO 80501, USA
# Phone Number: (303) 772-1169
# Website: http://eatatsantiagos.com/Longmont
# Rating: 4.4
# Place ID: ChIJn3qyZWb5a4cRLBRwz_KhWmY
#
# Recent Reviews:
# Author: Michelle F.
# Rating: 5
# Review: Some of the best green chili I've had in my entire life. I wish they made the breakfast burritos to order instead of only using one meat every day, since bacon gives me a migraine. But that's presumably a rare problem.  I got the Huevos Rancheros instead and it was just so gosh darn good. The fried potatoes, the green chili , the beans, all amazing. I'll come back another day to try the other types of breakfast burritos!
# Time: 5 months ago
#
#
# -----------------
#
# Author: Alli Morris
# Rating: 1
# Review: I was not impressed with the food or service. The counter staff was anything but welcoming. My husband's food was almost inedible because they had mistakenly made it ultra spicy and served it luke warm. We also paid $4 for on small scoop of brown guacamole. Pretty gross. I would have sent everything back if we had been dining-in but we took our order to go and ended up throwing most of it out.
# Time: a month ago
#
#
# -----------------
#
# Author: Mitzi Wimer
# Rating: 4
# Review: We had take out. The women that helped me was  very helpful  and the order  was ready very quickly.  I took the food to a friend and her husband . They were so thankful and very grateful.  They  loved the meal!!
# Time: a month ago
#
#
# -----------------
#
# Author: Mark Peterson
# Rating: 1
# Review: I have been going here for years. Stop bye pick up a breakfast burrito and on my way. This time my son and I decide to sit in the restaurant. We ordered the same thing we always do, 2 burritos each. I got the bill and was completely shocked. With 20% tip it was $44.00. They charge you as much to smother it as the burrito cost and they charge per burrito. I pointed this out to the waitress and she said that's the way the computer does it. Geez that's you excuse for over charging people? Last time for me in this place. My heart will be happy. Less lard.
# Time: a month ago
#
#
# -----------------
#
# Author: Razorhornet
# Rating: 5
# Review: This was a nice meal and great price! The food portions for shears and mild was actually kind of hot.  Chips and salsa were great!
# Time: 9 months ago
#
#
# -----------------
#
# Name: El Tapatio Mexican Restaurant
# Address: 588 Summit Blvd, Broomfield, CO 80021, USA
# Phone Number: (720) 383-6201
# Website: https://eltapatiomexican.net/588-summit-blvd
# Rating: 3.9
# Place ID: ChIJTR_ea4WMa4cRJequlENJNzQ
#
# Recent Reviews:
# Author: Leo Mendoza
# Rating: 5
# Review: Good place to eat, had the pork carnitas for dinner with a few friends and coworkers. The staff was great and food came out in a timely manner. Restaurant was clean and overall a nice atmosphere!! I’ve been to their other locations, also good!! I Will be sure to visit again! Thank you!
# Time: 3 months ago
#
#
# -----------------
#
# Author: KARINA ALVAREZ
# Rating: 1
# Review: This is the second time I come to this restaurant, and get charged for this.  I am aware that .50 is not a lot of money, but when this is being charged to everyone that orders a Michelada, that's quite a bit of money.  I have attached photos where you can see that the "Michelada I ordered in the drink menu is $8. As you can see "clamato" is part of the ingredients for this drink. I have also included my receipt, where you can see that they are charging me an additional .50 for the clamato when the clamato is included in the Michelada.  Last time I went there, we ordered about 4 Micheladas total, so that's $2.00 they over charged for that visit, and again last night for the drink I ordered.  No where on that menu does it state that Clamato is an extra charge.  I just thought people should know that this restaurant is over charging you for this and who knows what else.  So pay attention to your receipt before you pay.
# Time: a month ago
#
#
# -----------------
#
# Author: Kayla
# Rating: 5
# Review: Wish I could give them 7 stars for service! Everyone working was very friendly! Food was delicious as well. Will definitely be back!
# Time: 2 months ago
#
#
# -----------------
#
# Author: Brianna Manchini
# Rating: 5
# Review: We’ve been here a few times and every time we leave satisfied and happy. I think this place is a little more on the expensive side for Mexican food but it is so delicious and so worth what you pay for it. Our servers are always nice and speak to us respectfully. The nachos are arranged perfectly as an appetizer (or if you’re me you’ll enjoy them all by yourself), the margaritas are a great size and so unnecessary good….like why are they so good? Shrimp and steak fajitas were also 10/10. We will be coming back as we always do.
# Time: a year ago
#
#
# -----------------
#
# Author: Katherine D
# Rating: 3
# Review: Overall so-so. Service was fast! Bar doesn’t give drink menus which I thought was a little weird, but can’t go wrong with a jumbo margarita. Had the carne asada plate. Little tough. Guac didn’t taste house-made.
# Time: 7 months ago
#
#
# -----------------
#
# Name: El Azteca Mexican Food
# Address: 2683 E 120th Ave, Thornton, CO 80233, USA
# Phone Number: (303) 252-8884
# Website: https://elaztecamexicanfood.com/
# Rating: 4.3
# Place ID: ChIJe0T0bhd0bIcR1qrSV_wWeWc
#
# Recent Reviews:
# Author: Marlo Olivas
# Rating: 2
# Review: This place was absolutely delicious! I had an amazing meal here. I ordered the torta with asada and a chili relleno, and it was smothered in delicious sauce. The food was definitely the highlight of my experience. However, I must admit that the customer service was a bit disappointing. The young lady who assisted me was quite rude. As a first-time visitor, I was a bit confused about the menu and when I mentioned it was my first time, her response was rather snarky, saying "well, that makes a lot of sense." She didn't seem interested in helping me understand their food options. Despite the subpar service, I would still consider going back for the amazing food, but I hope the service improves in the future.
# Time: 3 weeks ago
#
#
# -----------------
#
# Author: Alaynna Williams
# Rating: 5
# Review: My boyfriend and I stopped here on our way from Loveland to Echo Mountain and it was so good! I am a personal Mexican Food fan and this was definitely one of the best I have had. The food was warm, flavorful, and large portions so you will definitely have leftovers! The prices were reasonable as well. The food came out quick and the staff were all super friendly and attentive. Everything was clean as well which was nice.  I definitely recommend!
# Time: in the last week
#
#
# -----------------
#
# Author: Mario Dorado
# Rating: 4
# Review: Food is pretty good for Mexican food in Thornton or in CO in general. I judge a place by the tortillas they use in burritos and they have good burritos. You can tell it’s very Americanized and of course smothered is a thing. I’m not from Colorado and not a fan. Salsa is another great tell and their salsa is pretty good. All in a pretty well priced, so that’s why I gave it a 4.
# Time: in the last week
#
#
# -----------------
#
# Author: Jason Robb
# Rating: 5
# Review: Always delicious. I go here all the time! The service is fast and always super friendly! They are always so kind and helpful! The dining area is simple. Always clean but not really restaurant style. There are seats, but it feels more like a place to sit and wait for Togo food, but you are more than welcome to eat in. Tonight I ordered chicken nachos and veggies fajitas. The nachos come with a generous portion of chicken on a nice bed of chips. It comes with beans, Pico, sour cream and guacamole and some shredded cheese. I would order with extra cheese if I were you! The fajitas are delicious! Very flavorful and the vegetables were cooked delightfully. Not to soft not to hard. Very well seasoned! The rice is usually bland but the beans are good. It's a decent portion. I've had bigger at some places and smaller at others. Their beans are good. By default it comes with one flour tortilla. Idk if they offer corn tortillas instead I have never tried. Everything I have had here has always been good! 9/10 definitely recommended
# Time: 7 months ago
#
#
# -----------------
#
# Author: Broooks75 75
# Rating: 4
# Review: Inside is 100% barren. Got the carne asada fries. Needs more sour cream. It is a super dumb thing to request but it has to blend out the overall flavor. Nice and hot for a first time food outing at Azteca. Hot sauce , the green one is okay. Will have to try something else. Perhaps a burrito. Northern food places , Thorton and Northglenn have never wowed me except for Q Table.  Overpriced! I know inflation affects many places. But 13 dollars? Restaurants have been passing on their prices to consumers.  Azteca, is worth a look.
# Time: 3 weeks ago
#
#
# -----------------
#
# Name: Lupita's Mexican Restaurant
# Address: 75 W Bridge St, Brighton, CO 80601, USA
# Phone Number: (303) 484-1007
# Website: https://www.lupitasmexicanrestaurantbrighton.com/order
# Rating: 4.4
# Place ID: ChIJV_x1NsltbIcR6b3lfXmciwA
#
# Recent Reviews:
# Author: Luis Gonzalez
# Rating: 5
# Review: It was late when we went I thing about half hour till they closed. But the food was great. The servings were enormous. And great tasting. The chips and dip they have are amazing. I had a 3 item combination of 2 cheese enchiladas and a burrito.
# Time: 5 months ago
#
#
# -----------------
#
# Author: Veronica DeLorey
# Rating: 5
# Review: Always a good time. Food is reliably good same for service. It took me a minute to warm up to over 3 Margs. But they are our go to restaurant even for breakfast. We've gone here many times and never a bad experience. Their drinks are a force to be reckoned with so make sure there is a safe driver.
# Time: a month ago
#
#
# -----------------
#
# Author: Tim Walker
# Rating: 4
# Review: Not a hole-in-the-wall! Big roomy restaurant with a long menu. I can vouch for the menudo! A little run down. A nice visit over lunch on a Saturday - not too busy. Nice bar.
# Time: 7 months ago
#
#
# -----------------
#
# Author: Juliana Freelong
# Rating: 5
# Review: Waitress wasn't the best but 5 star food all around! The large plate was HUGE! Amazing food and bf fajitas were amazing to him and he is picky!
# Time: 10 months ago
#
#
# -----------------
#
# Author: Courtney Dillon
# Rating: 5
# Review: My partner and I have frequented Lupita’s over the last month. We just moved to Brighton a few months ago and it’s the only restaurant we have truly loved up here! Great staff, great food, and a really welcoming atmosphere. Plus the homemade tortillas they do are so phenomenal. Definitely recommend!
# Time: 3 months ago
#
#
# -----------------
#
# Name: 3 Margaritas Longmont
# Address: 2350 Main St, Longmont, CO 80501, USA
# Phone Number: (303) 682-0888
# Website: https://www.3margaritaslongmont.com/
# Rating: 4.2
# Place ID: ChIJ_ZyT_zX5a4cR2zEeFLuT2As
#
# Recent Reviews:
# Author: BMF Garage
# Rating: 4
# Review: We’ve ate at this place many times, and it’s always a solid experience.  The chips and salsa is always full and they have a mild and regular version of the salsa.  Service at this place is my favorite.  Always attentive and helpful.  I had the Chile Colorado.  It had good flavor and hit the spot with the beans and rice with corn tortillas.  Wife and son had fajitas… steak and chicken.   They were fantastic, flavorful and finished them all.  Little one had the chicken tenders and fries and loved them.  She said the ranch is bangin!!!  Also had the divorcidas enchiladas.  They were all three delicious.
# Time: 5 months ago
#
#
# -----------------
#
# Author: Razorhornet
# Rating: 5
# Review: Military discount! Great atmosphere fast on the food. It was under 20 bucks for a burrito and a big old beer. I love it! And it was so so so good!
# Time: 2 months ago
#
#
# -----------------
#
# Author: Cory J
# Rating: 5
# Review: I was very impressed with this restaurant. After having a bad experience at the 3 Margaritas in Westminster we hadn't tried it for several months. This location is huge, and very well put together. It looks well suited to host an event with plenty of seating and an open space for dancing. We were seated immediately and had the choice of the outdoor patio or booth seating inside. We met my grandmother there and they had already brought chips and 2 different salsas to the table. Our waitress was polite and the food came out quickly and was delicious. The portions were big and piping hot. The manager, possibly the owner also came by about mid-way through our meal to make sure we were happy with our food and service. We will return to this location. I'm happy that this restaurant changed my mind about 3 Margaritas as a whole. My one bad experience (at another location) will only keep me away from that particular place.
# Time: 4 months ago
#
#
# -----------------
#
# Author: Jenny Hoppe
# Rating: 5
# Review: Food was wonderful here! We were driving through and everyone wanted authentic Mexican food. We made it for the lunch specials and majority of the items were $10.99 with large portions! the free chips and salsa were good and you are provided 2 different types of salsa. We all ordered a round of margaritas and they were wonderful too. 😊 Lunch time was slow (Wednesday) so it's the time to go if you want a quiet place but we had excellent service!
# Time: 4 months ago
#
#
# -----------------
#
# Author: zola parker
# Rating: 5
# Review: Very good food and service. No problem with refills on drinks or chips. Our food came out in good timr and pipping hot. Wish we could afford to go there more often. Love this place.
# Time: a month ago
#
#
# -----------------
#
# Name: Mucho Bueno Mexican Restaurant
# Address: 9740 Grant St #85, Thornton, CO 80229, USA
# Phone Number: (720) 638-5132
# Website: https://www.muchobuenocolorado.com/
# Rating: 4.7
# Place ID: ChIJBdjhicp3bIcRiKFG4fWvq3U
#
# Recent Reviews:
# Author: Cierra
# Rating: 5
# Review: The food here is delicious! Great for anyone seeking out Mexican food. Menu has a lot of variety. The portions were big, and the salsa was perfect. The staff was very attentive and nice, and we were seated very quickly. Looking forward to our next visit!
# Time: 3 months ago
#
#
# -----------------
#
# Author: Stephikins Sandoval
# Rating: 5
# Review: We love, love, love Mucho Bueno! A hidden gem in Thornton,  Great Food, Friendly Staff. They treat you like family. The portions are big and so is the heart at this place! My Hubby had the Mexican hamburger,  yummy! I had Tacos El Carbon! People if it wasn't great food our plates wouldn't look like this!
# Time: 8 months ago
#
#
# -----------------
#
# Author: Stacy Veith
# Rating: 3
# Review: I ordered steak birria Ramen which turned out to be steak caldo with Ramen noodles. It had no cilantro, onions or lime. It was not like any other I had before from other restaurants that use the consome. It was veggie caldo that they put steak in. It was bland and not tasty. I had to add flavor at home The bread was Texas toast not the torta bread like at other places. The only reason it looks red in the picture is because I added hot sauce For the price it was very disappointing. To be honest Del taco has better.
# Time: 2 weeks ago
#
#
# -----------------
#
# Author: C Ervin
# Rating: 5
# Review: Some places don't do their name justice... This one tho lives up theirs!!! I was nervous about finding good Mexican food in Colorado. I travel a lot in south Texas, my wife is Mexican, and her family lives about 10 minutes from the border ~ so I've become spoiled and picky on what good Mexican food is. This place checks all the boxes ✅ I'll definitely be back next time I'm in the area!!
# Time: 7 months ago
#
#
# -----------------
#
# Author: courtney lanning
# Rating: 5
# Review: the workers are so nice! only ordered takeout but they were cheerful, polite, and quick from the moment i walked in. definitely gonna come and dine in some other day, the food was great and i believe they’d make it a very pleasant experience.
# Time: 2 weeks ago
#
#
# -----------------
#
# Name: El Taco Loco II
# Address: 909 Carbondale Dr, Dacono, CO 80514, USA
# Phone Number: (303) 833-6890
# Website: https://www.facebook.com/Eltacololoco/
# Rating: 4.1
# Place ID: ChIJ0wI1J7YObIcRkRK2fphdagY
#
# Recent Reviews:
# Author: 2A Freedom
# Rating: 5
# Review: Wow! Great service, great atmosphere, and Amazing Food! Huge portions, you'll want to share. Salsas are on point. Very reasonable prices for the amount. I totally recommend this place. We're definitely coming back. we need to try more!
# Time: a month ago
#
#
# -----------------
#
# Author: Sherry Fairow
# Rating: 3
# Review: The food was wonderful. We had not so good serves, hard to communicate with server.  The prices have went way up, we took 3 adults and a child spent over 80.00 so not a value of any sorts but the food is still fire!!
# Time: 2 months ago
#
#
# -----------------
#
# Author: Fiestas303
# Rating: 4
# Review: Update: I want to believe they were having an off day, however service was taking extremely long, products were not cooked well; overcooked or simply not as fresh as should be. The octopus on a molcajete del Mar was frozen dry. Not even the texture was there much less the flavor. While a molcajete del Mar seems appealing Molcajetes main appeal is for hot food, I expected something special but it was lacking seasoning,flavor and most of all freshness on octopus; it's suppose to have oysters according to the menu but there were none. Their meats molcajete is good but this seemed more like an overpriced coktel or campechana.  The shrimp rellenos were cooked dry, maybe premade and cooked once again, the rice was hard maybe from dryness ,not completely cooked or reheated too many times. They were struggling as far as service with almost full house, but service and teamwork seems flawed.  I mention these things so you can improve and put forth the effort to provide better experience for customers. I rarely go on weekend and had only been during week  for brunch and they seemed to handle the crowd well earlier in the day on Saturday.  Not sure what's going on but sure hope they're able to iron the details and be able to handle the crowds much better.  Old review: This place is great value, delicious, their service has always been good and gotten better. While I've tried various items from carne asada tacos, to Costello, to fajitas lately at least the last 2 times I had their tacos de barbacoa.  I was about to order a molcajete which seem to be new items on the menu however I recalled the tacos were to die for and wanted to confirm if they're spectacular or they had a fluke.  The tacos ended tasting better than I recall. They are so soft and juicy without drowning and sogging the tortilla to point it breaks. The only weakness is the tortilla however since they heat them up properly its a split second I get a whiff of scent they give off. If not heated properly I could not eat type of tortillas. The calamari was pretty good but not as tasty as previous time. This may have been prebatterred or store bought but still delicious.  The barbacoa dish you can get 3 tacos beans and rice or 4 tacos and no beans no rice. Since I had the calamari I opted for the 4 tacos.  Those tacos were AMAZING!
# Time: a year ago
#
#
# -----------------
#
# Author: Michelle Arrick
# Rating: 5
# Review: This is the place to go if you want truly authentic food. The selection is amazing and we love this place!! We will continue to eat here and recommend them to everyone we know (and even some we don't)!
# Time: 3 months ago
#
#
# -----------------
#
# Author: snoyak
# Rating: 5
# Review: Best breakfast burritos anywhere! Comes with a side of green salsa that adds that little xtra something. Hands down the best breakfast burritos! The whole menu is delicious. Service can be spotty depending on the server. That doesn’t take away from the food.
# Time: 5 months ago
#
#
# -----------------
#
# Name: Buenos Tiempos
# Address: 1000 Depot Hill Rd, Broomfield, CO 80020, USA
# Phone Number: (303) 466-6386
# Website: http://www.buenostiemposrestaurant.com/
# Rating: 4.5
# Place ID: ChIJpbA7vVWLa4cRC3E7MTxvzsg
#
# Recent Reviews:
# Author: Kirsten Peterman
# Rating: 5
# Review: The steak fajita burrito was fabulous tonight!! This is my local favorite for Mexican food. I've been a frequent diner here for MANY years. Outstanding service, friendly staff, and speedy service!
# Time: 3 months ago
#
#
# -----------------
#
# Author: Courtney Gimeno
# Rating: 5
# Review: Being a Colorado native and trying to find decent Mexican food, this place is far from disappointing. They have some amazing Mexican but also offer so many other dishes. The burgers are the best I’ve ever had. Definitely a must try place. You wouldn’t think pulling up but it’s incredible. The service is also top notch and you walk in and feel like family. So many regulars and just a good feel place. Lots of pool tables, music on the box, and other games.
# Time: 2 months ago
#
#
# -----------------
#
# Author: Tina Correa
# Rating: 5
# Review: Best margaritas on town. Delicious green chili, fajitas are my favorite. The best part is the staff, they are friendly, welcoming and provide great service. Check out this local fav.
# Time: a week ago
#
#
# -----------------
#
# Author: M N
# Rating: 5
# Review: A local favorite restaurant featuring homemade dishes. My favorite go-to plate is the green chili Mac with perfectly cooked chicken and perfectly cooked shrimp. The red chili is fantastic along with the daily food and drink specials. Prices are reasonable. Our server, Anders, is exceptional! He makes you feel right at home with his warm personality and caring service. I highly recommend this restaurant. There is a bar on other side of restaurant with pool tables. I don't have too much info in that side, as I am only interested in the restaurant side.
# Time: 10 months ago
#
#
# -----------------
#
# Author: Rumi Arakawa
# Rating: 5
# Review: This place is great! Lunch price is so generous. This fajita salad and Enchiladas are both under $10. Taste was great and I usually can’t finish untie plate but I did and even ordered desserts. Sopapilla was a little too big for my liking but taste was great and the Flan was so delicious. Definitely coming back!
# Time: 2 years ago
#
#
# -----------------
#
# Name: Si Señor! Real Mexican Food
# Address: 3120 Village Vista Dr, Erie, CO 80516, USA
# Phone Number: (720) 890-9765
# Website: https://www.sisenorrealmexicanfood.com/
# Rating: 4.1
# Place ID: ChIJFanim5AKbIcRyBOO2L1MYS4
#
# Recent Reviews:
# Author: Robbie Stage
# Rating: 5
# Review: Really great Mexican restaurant! The chips came out hot and the salsa was made with chile. The burrito I had was delicious and the green chili was very flavorful. The margaritas are also very good and big if you get anything bigger than a small (medium pictured). The service was amazing and everyone was very attentive. I'm excited to go back!
# Time: 3 months ago
#
#
# -----------------
#
# Author: Gregg Harper
# Rating: 2
# Review: It was the first time visiting this establishment. I want to start with the positive: the dining room is decorated well and inviting. After that, it goes downhill. The server had no personality and did not seem to care about our experience. We ordered the dip sampler and both of us ordered the ground beef stuffed sopapilla. The sampler was mediocre; you could tell the guacamole was not made in restaurant. The so-called stuffed sopapillas were deep fried flour tortillas with meat inside. The green chile was also not very good; did not taste like it was made in the restaurant. To make it worse, the prices were outrageous for the kind of food we got. At this point, I don't think I would go there again
# Time: 5 months ago
#
#
# -----------------
#
# Author: Lara Djo
# Rating: 5
# Review: Monica was absolutely delightful, the food was so authentic and we couldn’t be happier with our first experience! We’ll definitely be back! The beef tortilla soup was so delicious and the margs were on point - oh and the salsa was amazing!
# Time: 2 months ago
#
#
# -----------------
#
# Author: Emily Ulibarri
# Rating: 5
# Review: This has quickly become our absolute favorite place to eat! It is now our weekly date night! The food is hands down the best in the state! The staff is absolutely amazing and the atmosphere is so welcoming! I would highly highly recommend!
# Time: 2 months ago
#
#
# -----------------
#
# Author: Janet Dybek
# Rating: 5
# Review: Great service. Yummy tacos n pozole!
# Time: a week ago
#
#
# -----------------
#
# Name: ANA'S Mexican Grill
# Address: 2821 W 120th Ave #100, Westminster, CO 80234, USA
# Phone Number: (303) 465-6472
# Website: http://anasmexicangrill.com/
# Rating: 4.4
# Place ID: ChIJUV4SyPJ1bIcR0GZVKfRDHys
#
# Recent Reviews:
# Author: Nicole Hall
# Rating: 5
# Review: You can never go wrong with the peach margaritas! They are delicious.  I've always gotten the fried chicken tacos and the queso.  Food it's always fresh tasting and staff is always super friendly and kind to everyone.  Definitely check they out. You will not be disappointed.
# Time: 10 months ago
#
#
# -----------------
#
# Author: Marc Carr
# Rating: 5
# Review: The food is always excellent and the staff is awesome and so attentive. The prices are great for the quality and generous serving size. We always have the best time when we go to Ana's.
# Time: 2 weeks ago
#
#
# -----------------
#
# Author: Kelly Wecker
# Rating: 5
# Review: Anna's is our go to Mexican food! We live near by and have tried multiple things on the menu. My favorite is everything you really can't go wrong but if I really had to choose....The steak fajitas and of course the house margarita is an absolute must!!! We are never disappointed, the food and the service is always amazing!
# Time: 2 months ago
#
#
# -----------------
#
# Author: Joicartoon B
# Rating: 1
# Review: We have been wanting to try Ana's for a while now. We heard great things, and we love supporting the Mexican restaurants here in the community. Tonight we decided to give it a shot.... mistake... we walked in, were greeted and shown to our table. We sat there waiting for over twenty minutes to get service. A server walked by so I asked if we could grab some drinks. She just walked by and held a stop ✋️ hand signal in our face! When she walked back by she completely ignored us! Completely uncalled for, and rude. So we just got up and walked out! We decided to go to El Mirador for quality Mexican food and true service! We won't be back to Ana's!
# Time: 2 months ago
#
#
# -----------------
#
# Author: Jessica Lindeman
# Rating: 5
# Review: Amazing food! Very authentic Mexican cuisine. Their salsa is to die for, super chunky and spicy! Price points are a little high but very much worth it. The happy hour margarita is good but the Ana’s Special Margarita will knock your socks off!
# Time: 5 years ago
#
#
# -----------------
#
# Name: Santiago's Mexican Restaurant
# Address: 104 N Public Rd, Lafayette, CO 80026, USA
# Phone Number: (303) 604-0715
# Website: http://eatatsantiagos.com/
# Rating: 4.3
# Place ID: ChIJ4_1_ffr0a4cRaf2roIbZOuk
#
# Recent Reviews:
# Author: Hiromy Pfosi
# Rating: 3
# Review: This is one of my hubby's go to places for a quick burrito as he really likes their spicy salsa. I think they're ok and will go occasionally. We decided to grab some food for a quick dinner, he got his usual burrito and I ordered the Fajitas (chicken). His burrito was done quickly but it appears they forgot my fajitas so finally after waiting and having several customers who ordered after us get their food, we asked about it. The gentleman my husband spoke to was not friendly to either of us and seemed put off that we asked. We finally got our food and I thanked him with no response. The fajitas were only passable and definitely not worth the money or the attitude. I probably won't go back because there is another local place where the service has been always friendly and the food is very tasty especially for the price.
# Time: 3 months ago
#
#
# -----------------
#
# Author: nathan reynolds
# Rating: 4
# Review: I would give Santiago's five stars overall but it detracts from the no frills Denver Mexican food legend status Santiago's has earned with consistently good food, and legendary green Chile. You will not be displeased by eating at Santiago's and will come back for that Green Chile craving again and again.
# Time: 2 weeks ago
#
#
# -----------------
#
# Author: Chris Cooper
# Rating: 2
# Review: Stopped by at 10:30a on a Saturday for a breakfast burrito, only to be told they’re not serving them.  It isn’t hard to include this information on your website or menu. Even as I write this the breakfast burritos are available on their app for pick up. Very disorganized.
# Time: 2 weeks ago
#
#
# -----------------
#
# Author: Brian Baker
# Rating: 5
# Review: Great food at a fantastic price.  Got a small combo, plus chips and salsa.  Though the chips and salsa weren't free, they weren't expensive either and there was plenty of them.  The small combo was more food than I could handle in one sitting!  The chile tasted great, though I admit I was hoping the hot would be spicier.
# Time: 4 years ago
#
#
# -----------------
#
# Author: Larry Vorwerck
# Rating: 5
# Review: Great food. Not much for atmosphere, but has a small patio when weather gets better.
# Time: in the last week
#
#
# -----------------

# %% [markdown]
# ### Send Reviews to the Unicorn model for Summary

# %% [markdown]
# Get `place_id` of restaurants

# %%
from google.colab import auth as google_auth
google_auth.authenticate_user()

# Used to pull in API Keys/Secrets
from dotenv import load_dotenv
import os
# Load environment variables from .env file
load_dotenv()
api_key = os.getenv("api_key")
project_id = os.getenv("project_id")

import requests
import math
import vertexai

from vertexai.preview.language_models import TextGenerationModel

# Define the search radius and other parameters
location_name = 'Erie, Co'  # Replace with the city or town of your choice
radius = '20000'  # 20000 is approx 20 miles
place_type = 'restaurant'
keyword = 'mexican'

# Haversine function to calculate distance
def haversine(lat1, lon1, lat2, lon2):
    """Calculate the great circle distance in kilometers between two points
    on the earth (specified in decimal degrees)"""
    lat1, lon1, lat2, lon2 = map(math.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a))
    r = 3956  # Radius of earth in kilometers. Use 3956 for miles
    return c * r

# Function to convert a location into latitude and longitude
def get_location_coordinates(api_key, location):
    geocode_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={api_key}"
    response = requests.get(geocode_url)
    data = response.json()
    if 'results' in data and len(data['results']) > 0:
        latitude = data['results'][0]['geometry']['location']['lat']
        longitude = data['results'][0]['geometry']['location']['lng']
        return f"{latitude},{longitude}"
    else:
        return None

# Get the latitude and longitude for the location
location_coordinates = get_location_coordinates(api_key, location_name)
if not location_coordinates:
    raise Exception("Failed to get location coordinates. Check your location name and API key.")

# Split the coordinates into latitude and longitude for distance calculation
location_lat, location_lon = map(float, location_coordinates.split(','))

# Endpoint URL for the Nearby Search request
url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={location_coordinates}&radius={radius}&type={place_type}&keyword={keyword}&key={api_key}"

# Make a GET request to the Google Maps API
response = requests.get(url)
data = response.json()

# Collecting restaurant information
restaurant_details_string = ""

if data.get('results'):
    for place in data['results']:
        name = place.get('name', 'No name available')
        address = place.get('vicinity', 'No address available')
        rating = place.get('rating', 'No rating available')
        place_id = place.get('place_id', 'No place ID available')  # Extract place_id
        open_now = 'No information available'
        if 'opening_hours' in place and 'open_now' in place['opening_hours']:
            open_now = 'Yes' if place['opening_hours']['open_now'] else 'No'
        place_lat = place['geometry']['location']['lat']
        place_lon = place['geometry']['location']['lng']
        distance = haversine(location_lat, location_lon, place_lat, place_lon)

        # Append restaurant information to the string
        restaurant_details_string += f"Name: {name}, Address: {address}, Rating: {rating}, Open Now: {open_now}, Distance: {distance:.2f} miles, , Place ID: {place_id}\n\n"
else:
    print("No nearby restaurants found or an error occurred.")

#paste in reviews
def get_place_details(api_key, place_id):
    """Fetch place details for a given place_id from the Google Places API."""
    details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&key={api_key}"
    response = requests.get(details_url)
    data = response.json()

    if data['status'] == 'OK':
        # Extract and print details
        details = data['result']
        name = details.get('name', 'No name available')
        place_id = details.get('place_id', 'No place ID available')

    else:
        print("Error fetching details:", data.get('status', 'Unknown error'))

# Main Script
def main():
    location_coordinates = get_location_coordinates(api_key, location_name)
    if not location_coordinates:
        raise Exception("Failed to get location coordinates. Check your location name and API key.")

    location_lat, location_lon = map(float, location_coordinates.split(','))

    url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={location_coordinates}&radius={radius}&type={place_type}&keyword={keyword}&key={api_key}"
    response = requests.get(url)
    data = response.json()

    if data.get('results'):
        for place in data['results']:
            name = place.get('name', 'No name available')
            place_id = place.get('place_id', 'No place ID available')

            # Print restaurant information
            print(f"Name: {name} :: Place ID: {place_id}\n")

            # Fetch and print details for each place_id
            get_place_details(api_key, place_id)
    else:
        print("No nearby restaurants found or an error occurred.")

if __name__ == "__main__":
    main()
# Out:
# Name: Tequila's Family Mexican Restaurant :: Place ID: ChIJg_2L-DN0bIcRMwQn9Yp1oAo
#
# Name: El Mirador Mexican Restaurant :: Place ID: ChIJWQxkTNd1bIcRLxnv6tU8zqs
#
# Name: Hacienda Colorado :: Place ID: ChIJ6ZWIs4CJa4cRIv72q1jsgL0
#
# Name: La Estrellita :: Place ID: ChIJZ6ZfmThtbIcRJo6l85no6co
#
# Name: Los Jimadores :: Place ID: ChIJQTCMOj5tbIcRke08jqvwKIU
#
# Name: Casa Agave :: Place ID: ChIJGfokW5f5a4cRB5ofRjjXl6Y
#
# Name: Rio Grande Mexican Restaurant :: Place ID: ChIJJU2aYSbsa4cRJC5YrD0nPFs
#
# Name: 3 Margaritas :: Place ID: ChIJlUT1r0ZxbIcRC9Oq2QiuSoU
#
# Name: El Aguascalientes Mexican Restaurant :: Place ID: ChIJHVe2cWttbIcRC5hWYyL6jS0
#
# Name: Santiago's Mexican Restaurant :: Place ID: ChIJn3qyZWb5a4cRLBRwz_KhWmY
#
# Name: El Tapatio Mexican Restaurant :: Place ID: ChIJTR_ea4WMa4cRJequlENJNzQ
#
# Name: El Azteca Mexican Food :: Place ID: ChIJe0T0bhd0bIcR1qrSV_wWeWc
#
# Name: Lupita's Mexican Restaurant :: Place ID: ChIJV_x1NsltbIcR6b3lfXmciwA
#
# Name: 3 Margaritas Longmont :: Place ID: ChIJ_ZyT_zX5a4cR2zEeFLuT2As
#
# Name: Mucho Bueno Mexican Restaurant :: Place ID: ChIJBdjhicp3bIcRiKFG4fWvq3U
#
# Name: El Taco Loco II :: Place ID: ChIJ0wI1J7YObIcRkRK2fphdagY
#
# Name: Buenos Tiempos :: Place ID: ChIJpbA7vVWLa4cRC3E7MTxvzsg
#
# Name: Si Señor! Real Mexican Food :: Place ID: ChIJFanim5AKbIcRyBOO2L1MYS4
#
# Name: ANA'S Mexican Grill :: Place ID: ChIJUV4SyPJ1bIcR0GZVKfRDHys
#
# Name: Santiago's Mexican Restaurant :: Place ID: ChIJ4_1_ffr0a4cRaf2roIbZOuk

# %%
import requests
import vertexai
from vertexai.preview.language_models import TextGenerationModel
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()
api_key = os.getenv("api_key")
project_id = os.getenv("project_id")

# Constants
MODEL_NAME = 'text-unicorn@001'  # Replace with the actual model name you have access to
PLACE_ID = 'ChIJHVe2cWttbIcRC5hWYyL6jS0'  # Replace with the place_id for the restaurant you're interested in

# Function Definitions
def get_place_reviews(api_key, place_id):
    """
    Fetch and return all reviews for a given place.

    Parameters:
        api_key (str): API key for Google Places API.
        place_id (str): The place ID to fetch reviews for.

    Returns:
        str: A string containing all reviews concatenated together.
    """
    details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&fields=name,rating,reviews&key={api_key}"
    response = requests.get(details_url)
    data = response.json()
    reviews = []

    if data['status'] == 'OK':
        for review in data['result'].get('reviews', []):
            text = review.get('text', '').replace('\n', ' ')
            reviews.append(text)
        all_reviews = ' '.join(reviews)  # Concatenate all reviews into a single text

        # Print all reviews for verification
        print("All Reviews:")
        for i, review in enumerate(reviews, 1):
            print(f"{i}: {review}\n")

        return all_reviews
    else:
        print("Error fetching details:", data.get('status', 'Unknown error'))
        return ""

def summarize_reviews(project_id, model_name, reviews):
    """
    Summarize the provided reviews using Text-Bison model.

    Parameters:
        project_id (str): Project ID for Vertex AI.
        model_name (str): The name of the model to use for generation.
        reviews (str): A string containing all reviews to summarize.
    """
    prompt = "Using the following reviews of this restaurant, generate a summary review that encompasses all opinions. Include a quote from one of the reviews, including the author's name. Reviews: "
    full_content = prompt + reviews  # Prepend the prompt to the reviews

    vertexai.init(project=project_id)
    model = TextGenerationModel.from_pretrained(model_name)
    response = model.predict(full_content, temperature=0.7, max_output_tokens=150)

    # Print the summarized reviews
    print("Summarized Reviews:")
    print(response.text)

# Main Script
def main():
    all_reviews = get_place_reviews(api_key, PLACE_ID)
    if all_reviews:
        summarize_reviews(project_id, MODEL_NAME, all_reviews)
    else:
        print("No reviews available to summarize.")

if __name__ == "__main__":
    main()
# Out:
# All Reviews:
# 1: The food was amazing the day we went the serive was great. And the servings are huge. My wife had the carnitas and I had a stake chimichanga.
#
# 2: Just stopped in and needed a few handheld burritos early on a Sunday morning ..reasonable prices and delicious burritos! The lady at the front was very nice. A little longer wait but that was because they were making things fresh and grilling the tortilla. Thanks!
#
# 3: No doubt that the food is good, and you get a great portion for a great price. But the service is not so great they take forever to get you anything or to do anything and not overly friendly and it smells really bad like sewer in there. There is very crowded. I think this facility should move somewhere else where it could do so much better, the smell of sewer is disgusting
#
# 4: Gave this place a shot as we were driving through, we are happy that we did. Food was great, service was quick and very helpful, atmosphere was well done, plenty of menu options for everyone. Recommend checking it out to anyone. We plan to go back next time we are in town.
#
# 5: Great authentic Mexican food from the tacos and burritos to pozole and menudo!
#
# Summarized Reviews:
#  This restaurant offers delicious and authentic Mexican food, with generous portions at reasonable prices. The service is generally good, but can be slow at times. The atmosphere is pleasant, but some customers have complained about a sewer smell. Overall, this is a great place to enjoy a meal with family or friends. "Great authentic Mexican food from the tacos and burritos to pozole and menudo!" - Anonymous
